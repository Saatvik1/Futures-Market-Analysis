# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
from datetime import datetime
import json
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('./IntermediateData/setup_data_export.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61027 entries, 0 to 61026
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      61027 non-null  object
#  1   Time      61027 non-null  object
#  2   Open      61027 non-null  float64
#  3   High      61027 non-null  float64
#  4   Low       61027 non-null  float64
#  5   Close     61027 non-null  float64
#  6   Session   61027 non-null  object
#  7   DateTime  61027 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 3.7+ MB

# %%
data.head()
# Out:
#          Date      Time      Open      High       Low     Close Session  \
# 0  10/18/2021  09:30:00  15076.50  15092.75  15060.25  15061.00     RTH
# 1  10/18/2021  09:35:00  15061.25  15088.00  15052.00  15083.25     RTH
# 2  10/18/2021  09:40:00  15083.00  15117.75  15074.75  15111.25     RTH
# 3  10/18/2021  09:45:00  15111.00  15135.50  15105.25  15135.00     RTH
# 4  10/18/2021  09:50:00  15134.75  15144.00  15125.00  15128.00     RTH
#
#    DateTime
# 0  09:30:00
# 1  09:35:00
# 2  09:40:00
# 3  09:45:00
# 4  09:50:00

# %% [markdown]
# # Algo to gather trades and results:
# get first 5m candle if high of candle is touched 1 tick above we enter at a position, with the SL being at the low of the 5m candle then we get stopped vice versa for shorts
#
# whatever the stop size is... that is the size for the TP as well... 1:1 RR
#
# after SL or TP, trade is done and we move onto the next day
#
# algo design:
#
# will need the use of vectorized functions, a loop would take too long on this size... and this would also improve my programming skill
#
# perhaps i can group by sessions and then run paramterized vector on that with for loops for each session
#
# if no trade in session (the whole thing is within 5m!!!) then ignore day... if trade but ends up in the 5m candle, just take difference of close and then entry to find the profit of points.
#
# first i can get rid of gbx sessions... we can keep premarket within and hour but stop at 4:10 PM EST. so 8:25AM - 4:10PM.
#
# the group the sessions together
#
# then run above algo

# %%
data_grouped = data.groupby(['Date'])

# %%
def getHighLow(candle):
    return {'High':candle['High'] + 0.25, 'Low':candle['Low'] - 0.25}

# %%
#sesh is the group being passed, in other words it is the RTH session for that day where we are looking for
#5m break trade. 
def getZanekTrade(sesh):
    #get first 5 minute candle
    first_fmc = sesh.iloc[0]
    
    #get limit order placement 
    limits = getHighLow(first_fmc)
    
    #begin for loop to get trade entry and direction, and the value of RR (if RR is 30, and direction is 
    #short, then entry - 30 is SL and entry + 30 is TP)
    entry = {'Location':0, 'Direction':'', 'RR':0, 'entry_time':None}
    
    candle_entry_num = 0
    
    for i, candle in sesh.iterrows():
        if candle['High'] >= limits['High']:
            
            #tagged limit order at ffm candle high
            entry['Location'] = limits['High']
            
            #set direction, since we tagged high first, we long 
            entry['Direction'] = 'Long'
            
            #get RR
            RR = limits['High'] - limits['Low']
            entry['RR'] = RR

            #record entry time
            entry['entry_time'] = candle['DateTime']
            
            #keep track of candle index:
            candle_entry_num = i
            
            break
        elif candle['Low'] <= limits['Low']:
            
            #tagged limit order at ffm candle high
            entry['Location'] = limits['Low']
            
            #set direction, since we tagged high first, we long 
            entry['Direction'] = 'Short'
            
            #get RR
            RR = (limits['Low'] - limits['High']) * -1
            entry['RR'] = RR
            
            #record entry time
            entry['entry_time'] = candle['DateTime']

            #keep track of candle index:
            candle_entry_num = i
            
            break
            
    if candle_entry_num is None:
        print("what the fuck")
        return
    
    # TP is entry + size of candle in the direction of the break, same for SL, except opposite direction, so basically SL is at the low of the candle, 
    # so RR is what we are risking and rewarding
    TP = entry['Location'] + RR if entry['Direction'] == 'Long' else entry['Location'] - RR
    SL = entry['Location'] - RR if entry['Direction'] == 'Long' else entry['Location'] + RR
    
    for i, candle in sesh.loc[candle_entry_num+1:].iterrows():
        if entry['Direction'] == 'Long':
            #if we long, and candle high hits TP, then thats the win
            if (candle['High'] >= TP):
                return (entry, candle['DateTime'], True)
            #if we long, and the candle low hits the SL, thats the loss
            elif(candle['Low'] <= SL):
                return (entry, candle['DateTime'], False)
        #short
        else:
            #if short, the high of the candle reach the SL then we lose trade
            if (candle['High'] >= SL):
                return (entry, candle['DateTime'], False)
            #if short, the low of the candle hits TP then we win the trade
            elif(candle['Low'] <= TP):
                return (entry, candle['DateTime'], True)

# %%
results = {}

#Loop through the groupedby object of the data 
for name, group in data_grouped:
    results[name] = getZanekTrade(group)

# %%
results
# Out:
# {('1/10/2022',): ({'Location': 15311.0,
#    'Direction': 'Short',
#    'RR': 104.25,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   True),
#  ('1/10/2023',): ({'Location': 11246.25,
#    'Direction': 'Long',
#    'RR': 108.5,
#    'entry_time': '10:10:00'},
#   '10:40:00',
#   False),
#  ('1/10/2024',): ({'Location': 16873.75,
#    'Direction': 'Long',
#    'RR': 34.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('1/11/2022',): ({'Location': 15578.75,
#    'Direction': 'Long',
#    'RR': 72.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/11/2023',): ({'Location': 11348.25,
#    'Direction': 'Long',
#    'RR': 57.5,
#    'entry_time': '09:35:00'},
#   '12:15:00',
#   True),
#  ('1/11/2024',): ({'Location': 17015.0,
#    'Direction': 'Long',
#    'RR': 40.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('1/12/2022',): ({'Location': 15926.25,
#    'Direction': 'Short',
#    'RR': 66.0,
#    'entry_time': '09:40:00'},
#   '10:05:00',
#   False),
#  ('1/12/2023',): ({'Location': 11440.5,
#    'Direction': 'Short',
#    'RR': 78.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('1/12/2024',): ({'Location': 17014.5,
#    'Direction': 'Long',
#    'RR': 40.75,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('1/13/2022',): ({'Location': 15967.0,
#    'Direction': 'Long',
#    'RR': 34.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/13/2023',): ({'Location': 11456.25,
#    'Direction': 'Long',
#    'RR': 39.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/14/2022',): ({'Location': 15458.75,
#    'Direction': 'Long',
#    'RR': 79.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('1/15/2024',): ({'Location': 16955.5,
#    'Direction': 'Short',
#    'RR': 11.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('1/16/2023',): ({'Location': 11602.0,
#    'Direction': 'Long',
#    'RR': 14.25,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   False),
#  ('1/16/2024',): ({'Location': 16940.25,
#    'Direction': 'Long',
#    'RR': 35.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/17/2022',): ({'Location': 15610.25,
#    'Direction': 'Long',
#    'RR': 23.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/17/2023',): ({'Location': 11579.75,
#    'Direction': 'Short',
#    'RR': 41.0,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('1/17/2024',): ({'Location': 16758.75,
#    'Direction': 'Short',
#    'RR': 84.5,
#    'entry_time': '09:35:00'},
#   '15:45:00',
#   False),
#  ('1/18/2022',): ({'Location': 15290.0,
#    'Direction': 'Short',
#    'RR': 83.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/18/2023',): ({'Location': 11679.75,
#    'Direction': 'Short',
#    'RR': 47.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('1/18/2024',): ({'Location': 17047.5,
#    'Direction': 'Long',
#    'RR': 53.0,
#    'entry_time': '09:40:00'},
#   '10:00:00',
#   False),
#  ('1/19/2022',): ({'Location': 15316.0,
#    'Direction': 'Long',
#    'RR': 61.75,
#    'entry_time': '09:35:00'},
#   '10:30:00',
#   False),
#  ('1/19/2023',): ({'Location': 11443.75,
#    'Direction': 'Long',
#    'RR': 47.25,
#    'entry_time': '09:40:00'},
#   '09:45:00',
#   False),
#  ('1/19/2024',): ({'Location': 17201.0,
#    'Direction': 'Long',
#    'RR': 35.0,
#    'entry_time': '09:40:00'},
#   '10:55:00',
#   True),
#  ('1/2/2024',): ({'Location': 16829.75,
#    'Direction': 'Short',
#    'RR': 44.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('1/20/2022',): ({'Location': 15221.25,
#    'Direction': 'Long',
#    'RR': 61.25,
#    'entry_time': '09:40:00'},
#   '09:55:00',
#   True),
#  ('1/20/2023',): ({'Location': 11388.25,
#    'Direction': 'Short',
#    'RR': 41.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/21/2022',): ({'Location': 14706.5,
#    'Direction': 'Short',
#    'RR': 112.25,
#    'entry_time': '09:40:00'},
#   '10:10:00',
#   True),
#  ('1/22/2024',): ({'Location': 17576.0,
#    'Direction': 'Long',
#    'RR': 48.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/23/2023',): ({'Location': 11714.25,
#    'Direction': 'Long',
#    'RR': 42.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('1/23/2024',): ({'Location': 17415.25,
#    'Direction': 'Short',
#    'RR': 73.0,
#    'entry_time': '09:35:00'},
#   '12:55:00',
#   False),
#  ('1/24/2022',): ({'Location': 14227.75,
#    'Direction': 'Long',
#    'RR': 85.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/24/2023',): ({'Location': 11883.75,
#    'Direction': 'Long',
#    'RR': 43.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('1/24/2024',): ({'Location': 17658.0,
#    'Direction': 'Short',
#    'RR': 37.75,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   False),
#  ('1/25/2022',): ({'Location': 14266.0,
#    'Direction': 'Long',
#    'RR': 82.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('1/25/2023',): ({'Location': 11713.0,
#    'Direction': 'Long',
#    'RR': 55.0,
#    'entry_time': '09:40:00'},
#   '09:50:00',
#   False),
#  ('1/25/2024',): ({'Location': 17674.75,
#    'Direction': 'Short',
#    'RR': 52.25,
#    'entry_time': '09:45:00'},
#   '10:20:00',
#   False),
#  ('1/26/2022',): ({'Location': 14407.75,
#    'Direction': 'Short',
#    'RR': 90.5,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('1/26/2023',): ({'Location': 12068.75,
#    'Direction': 'Long',
#    'RR': 52.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/26/2024',): ({'Location': 17534.75,
#    'Direction': 'Short',
#    'RR': 36.5,
#    'entry_time': '09:35:00'},
#   '10:25:00',
#   False),
#  ('1/27/2022',): ({'Location': 14275.75,
#    'Direction': 'Short',
#    'RR': 72.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/27/2023',): ({'Location': 12094.25,
#    'Direction': 'Long',
#    'RR': 52.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('1/28/2022',): ({'Location': 13967.75,
#    'Direction': 'Short',
#    'RR': 134.75,
#    'entry_time': '09:35:00'},
#   '10:50:00',
#   False),
#  ('1/29/2024',): ({'Location': 17557.0,
#    'Direction': 'Long',
#    'RR': 27.5,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('1/3/2022',): ({'Location': 16449.0,
#    'Direction': 'Long',
#    'RR': 71.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('1/3/2023',): ({'Location': 11142.0,
#    'Direction': 'Long',
#    'RR': 69.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('1/3/2024',): ({'Location': 16624.0,
#    'Direction': 'Long',
#    'RR': 42.75,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   False),
#  ('1/30/2023',): ({'Location': 12064.5,
#    'Direction': 'Short',
#    'RR': 46.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('1/30/2024',): ({'Location': 17653.75,
#    'Direction': 'Short',
#    'RR': 31.25,
#    'entry_time': '10:00:00'},
#   '10:50:00',
#   True),
#  ('1/31/2022',): ({'Location': 14522.0,
#    'Direction': 'Long',
#    'RR': 106.0,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('1/31/2023',): ({'Location': 12031.5,
#    'Direction': 'Long',
#    'RR': 62.75,
#    'entry_time': '09:40:00'},
#   '11:35:00',
#   True),
#  ('1/31/2024',): ({'Location': 17371.75,
#    'Direction': 'Short',
#    'RR': 55.0,
#    'entry_time': '09:40:00'},
#   '10:30:00',
#   True),
#  ('1/4/2022',): ({'Location': 16468.5,
#    'Direction': 'Short',
#    'RR': 43.75,
#    'entry_time': '09:40:00'},
#   '10:00:00',
#   True),
#  ('1/4/2023',): ({'Location': 11041.5,
#    'Direction': 'Long',
#    'RR': 80.0,
#    'entry_time': '09:40:00'},
#   '09:45:00',
#   False),
#  ('1/4/2024',): ({'Location': 16489.25,
#    'Direction': 'Long',
#    'RR': 46.25,
#    'entry_time': '09:35:00'},
#   '10:45:00',
#   True),
#  ('1/5/2022',): ({'Location': 16113.5,
#    'Direction': 'Short',
#    'RR': 103.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('1/5/2023',): ({'Location': 10853.25,
#    'Direction': 'Short',
#    'RR': 71.75,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   False),
#  ('1/5/2024',): ({'Location': 16486.75,
#    'Direction': 'Long',
#    'RR': 49.5,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('1/6/2022',): ({'Location': 15797.5,
#    'Direction': 'Long',
#    'RR': 125.75,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('1/6/2023',): ({'Location': 10935.25,
#    'Direction': 'Long',
#    'RR': 82.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/7/2022',): ({'Location': 15700.75,
#    'Direction': 'Short',
#    'RR': 77.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/8/2024',): ({'Location': 16548.5,
#    'Direction': 'Long',
#    'RR': 43.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('1/9/2023',): ({'Location': 11199.0,
#    'Direction': 'Short',
#    'RR': 45.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('1/9/2024',): ({'Location': 16666.0,
#    'Direction': 'Short',
#    'RR': 48.75,
#    'entry_time': '09:40:00'},
#   '10:05:00',
#   False),
#  ('10/1/2024',): ({'Location': 20161.75,
#    'Direction': 'Short',
#    'RR': 104.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('10/10/2022',): ({'Location': 11051.75,
#    'Direction': 'Short',
#    'RR': 74.5,
#    'entry_time': '09:35:00'},
#   '10:35:00',
#   True),
#  ('10/10/2023',): ({'Location': 15189.0,
#    'Direction': 'Short',
#    'RR': 30.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/10/2024',): ({'Location': 20340.25,
#    'Direction': 'Short',
#    'RR': 50.0,
#    'entry_time': '09:45:00'},
#   '10:05:00',
#   False),
#  ('10/11/2022',): ({'Location': 10892.5,
#    'Direction': 'Short',
#    'RR': 52.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('10/11/2023',): ({'Location': 15377.75,
#    'Direction': 'Long',
#    'RR': 55.0,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('10/11/2024',): ({'Location': 20318.0,
#    'Direction': 'Short',
#    'RR': 29.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/12/2022',): ({'Location': 10874.75,
#    'Direction': 'Long',
#    'RR': 69.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('10/12/2023',): ({'Location': 15403.25,
#    'Direction': 'Long',
#    'RR': 25.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/13/2022',): ({'Location': 10541.75,
#    'Direction': 'Long',
#    'RR': 57.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('10/13/2023',): ({'Location': 15328.75,
#    'Direction': 'Short',
#    'RR': 38.25,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('10/14/2022',): ({'Location': 11105.25,
#    'Direction': 'Short',
#    'RR': 102.5,
#    'entry_time': '09:40:00'},
#   '10:00:00',
#   True),
#  ('10/14/2024',): ({'Location': 20586.0,
#    'Direction': 'Long',
#    'RR': 45.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('10/15/2024',): ({'Location': 20644.25,
#    'Direction': 'Long',
#    'RR': 38.75,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   False),
#  ('10/16/2023',): ({'Location': 15234.75,
#    'Direction': 'Long',
#    'RR': 66.25,
#    'entry_time': '09:35:00'},
#   '10:30:00',
#   True),
#  ('10/16/2024',): ({'Location': 20300.0,
#    'Direction': 'Short',
#    'RR': 57.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('10/17/2022',): ({'Location': 11055.0,
#    'Direction': 'Long',
#    'RR': 56.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('10/17/2023',): ({'Location': 15113.25,
#    'Direction': 'Short',
#    'RR': 29.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('10/18/2021',): ({'Location': 15060.0,
#    'Direction': 'Short',
#    'RR': 33.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/18/2022',): ({'Location': 11376.5,
#    'Direction': 'Short',
#    'RR': 55.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('10/18/2023',): ({'Location': 15194.75,
#    'Direction': 'Long',
#    'RR': 69.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('10/19/2021',): ({'Location': 15337.25,
#    'Direction': 'Long',
#    'RR': 32.5,
#    'entry_time': '09:35:00'},
#   '10:55:00',
#   True),
#  ('10/19/2022',): ({'Location': 11192.75,
#    'Direction': 'Long',
#    'RR': 74.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/19/2023',): ({'Location': 15073.0,
#    'Direction': 'Short',
#    'RR': 36.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('10/2/2023',): ({'Location': 14907.75,
#    'Direction': 'Long',
#    'RR': 60.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('10/2/2024',): ({'Location': 19911.75,
#    'Direction': 'Short',
#    'RR': 55.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('10/20/2021',): ({'Location': 15408.25,
#    'Direction': 'Short',
#    'RR': 21.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/20/2022',): ({'Location': 11103.25,
#    'Direction': 'Short',
#    'RR': 58.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/20/2023',): ({'Location': 14864.0,
#    'Direction': 'Long',
#    'RR': 53.5,
#    'entry_time': '09:40:00'},
#   '10:10:00',
#   False),
#  ('10/21/2021',): ({'Location': 15366.5,
#    'Direction': 'Long',
#    'RR': 32.75,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('10/21/2022',): ({'Location': 11085.25,
#    'Direction': 'Long',
#    'RR': 90.25,
#    'entry_time': '09:40:00'},
#   '10:05:00',
#   True),
#  ('10/22/2021',): ({'Location': 15437.75,
#    'Direction': 'Long',
#    'RR': 33.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('10/23/2023',): ({'Location': 14573.75,
#    'Direction': 'Short',
#    'RR': 56.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('10/24/2022',): ({'Location': 11372.5,
#    'Direction': 'Long',
#    'RR': 72.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('10/24/2023',): ({'Location': 14815.0,
#    'Direction': 'Long',
#    'RR': 52.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('10/25/2021',): ({'Location': 15393.0,
#    'Direction': 'Short',
#    'RR': 41.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('10/25/2022',): ({'Location': 11572.25,
#    'Direction': 'Long',
#    'RR': 57.5,
#    'entry_time': '09:45:00'},
#   '09:50:00',
#   True),
#  ('10/25/2023',): ({'Location': 14668.5,
#    'Direction': 'Short',
#    'RR': 81.0,
#    'entry_time': '09:35:00'},
#   '11:50:00',
#   True),
#  ('10/26/2021',): ({'Location': 15632.5,
#    'Direction': 'Long',
#    'RR': 52.75,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   True),
#  ('10/26/2022',): ({'Location': 11493.5,
#    'Direction': 'Long',
#    'RR': 60.75,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('10/26/2023',): ({'Location': 14390.0,
#    'Direction': 'Short',
#    'RR': 69.25,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('10/27/2021',): ({'Location': 15566.0,
#    'Direction': 'Short',
#    'RR': 35.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/27/2022',): ({'Location': 11400.25,
#    'Direction': 'Short',
#    'RR': 64.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('10/27/2023',): ({'Location': 14306.5,
#    'Direction': 'Short',
#    'RR': 43.0,
#    'entry_time': '09:40:00'},
#   '09:45:00',
#   False),
#  ('10/28/2021',): ({'Location': 15653.75,
#    'Direction': 'Short',
#    'RR': 34.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('10/28/2022',): ({'Location': 11306.75,
#    'Direction': 'Long',
#    'RR': 100.75,
#    'entry_time': '09:35:00'},
#   '10:30:00',
#   True),
#  ('10/29/2021',): ({'Location': 15653.75,
#    'Direction': 'Long',
#    'RR': 38.25,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('10/3/2022',): ({'Location': 11060.75,
#    'Direction': 'Short',
#    'RR': 66.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('10/3/2023',): ({'Location': 14910.25,
#    'Direction': 'Long',
#    'RR': 37.0,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('10/3/2024',): ({'Location': 19979.75,
#    'Direction': 'Long',
#    'RR': 85.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('10/30/2023',): ({'Location': 14397.0,
#    'Direction': 'Long',
#    'RR': 62.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('10/31/2022',): ({'Location': 11453.0,
#    'Direction': 'Short',
#    'RR': 69.75,
#    'entry_time': '09:40:00'},
#   '10:30:00',
#   True),
#  ('10/31/2023',): ({'Location': 14373.5,
#    'Direction': 'Short',
#    'RR': 55.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('10/4/2022',): ({'Location': 11562.75,
#    'Direction': 'Long',
#    'RR': 48.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('10/4/2023',): ({'Location': 14803.75,
#    'Direction': 'Long',
#    'RR': 55.0,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   False),
#  ('10/4/2024',): ({'Location': 20236.0,
#    'Direction': 'Long',
#    'RR': 50.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('10/5/2022',): ({'Location': 11478.0,
#    'Direction': 'Short',
#    'RR': 61.25,
#    'entry_time': '09:40:00'},
#   '10:15:00',
#   True),
#  ('10/5/2023',): ({'Location': 14920.25,
#    'Direction': 'Long',
#    'RR': 31.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/6/2022',): ({'Location': 11657.25,
#    'Direction': 'Long',
#    'RR': 68.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('10/6/2023',): ({'Location': 14735.5,
#    'Direction': 'Short',
#    'RR': 65.75,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   False),
#  ('10/7/2022',): ({'Location': 11348.25,
#    'Direction': 'Long',
#    'RR': 52.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/7/2024',): ({'Location': 20160.75,
#    'Direction': 'Long',
#    'RR': 45.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/8/2024',): ({'Location': 20106.5,
#    'Direction': 'Long',
#    'RR': 33.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('10/9/2023',): ({'Location': 14968.25,
#    'Direction': 'Short',
#    'RR': 48.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('10/9/2024',): ({'Location': 20252.5,
#    'Direction': 'Short',
#    'RR': 37.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('11/1/2021',): ({'Location': 15829.5,
#    'Direction': 'Short',
#    'RR': 39.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('11/1/2022',): ({'Location': 11576.0,
#    'Direction': 'Short',
#    'RR': 43.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('11/1/2023',): ({'Location': 14546.25,
#    'Direction': 'Long',
#    'RR': 31.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('11/10/2021',): ({'Location': 16109.25,
#    'Direction': 'Long',
#    'RR': 67.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('11/10/2022',): ({'Location': 11330.75,
#    'Direction': 'Short',
#    'RR': 64.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('11/10/2023',): ({'Location': 15330.75,
#    'Direction': 'Long',
#    'RR': 25.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('11/11/2021',): ({'Location': 16074.75,
#    'Direction': 'Short',
#    'RR': 36.0,
#    'entry_time': '09:35:00'},
#   '10:30:00',
#   True),
#  ('11/11/2022',): ({'Location': 11583.75,
#    'Direction': 'Short',
#    'RR': 60.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('11/12/2021',): ({'Location': 16048.75,
#    'Direction': 'Short',
#    'RR': 29.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('11/13/2023',): ({'Location': 15509.5,
#    'Direction': 'Short',
#    'RR': 29.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('11/14/2022',): ({'Location': 11738.0,
#    'Direction': 'Short',
#    'RR': 47.75,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   False),
#  ('11/14/2023',): ({'Location': 15834.25,
#    'Direction': 'Long',
#    'RR': 44.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('11/15/2021',): ({'Location': 16247.75,
#    'Direction': 'Long',
#    'RR': 35.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('11/15/2022',): ({'Location': 12017.25,
#    'Direction': 'Short',
#    'RR': 46.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('11/15/2023',): ({'Location': 15966.75,
#    'Direction': 'Long',
#    'RR': 31.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('11/16/2021',): ({'Location': 16202.75,
#    'Direction': 'Long',
#    'RR': 53.75,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   True),
#  ('11/16/2022',): ({'Location': 11793.75,
#    'Direction': 'Short',
#    'RR': 42.75,
#    'entry_time': '09:45:00'},
#   '09:50:00',
#   True),
#  ('11/16/2023',): ({'Location': 15855.5,
#    'Direction': 'Long',
#    'RR': 30.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('11/17/2021',): ({'Location': 16292.25,
#    'Direction': 'Short',
#    'RR': 30.5,
#    'entry_time': '09:50:00'},
#   '10:10:00',
#   False),
#  ('11/17/2022',): ({'Location': 11587.5,
#    'Direction': 'Long',
#    'RR': 44.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('11/17/2023',): ({'Location': 15851.75,
#    'Direction': 'Short',
#    'RR': 22.0,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('11/18/2021',): ({'Location': 16402.75,
#    'Direction': 'Long',
#    'RR': 49.75,
#    'entry_time': '09:45:00'},
#   '10:10:00',
#   False),
#  ('11/18/2022',): ({'Location': 11762.5,
#    'Direction': 'Short',
#    'RR': 80.25,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('11/19/2021',): ({'Location': 16559.75,
#    'Direction': 'Long',
#    'RR': 43.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('11/2/2021',): ({'Location': 15889.5,
#    'Direction': 'Long',
#    'RR': 25.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('11/2/2022',): ({'Location': 11271.0,
#    'Direction': 'Short',
#    'RR': 70.25,
#    'entry_time': '10:10:00'},
#   '12:35:00',
#   True),
#  ('11/2/2023',): ({'Location': 14937.25,
#    'Direction': 'Long',
#    'RR': 33.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('11/20/2023',): ({'Location': 15962.5,
#    'Direction': 'Long',
#    'RR': 68.0,
#    'entry_time': '09:35:00'},
#   '12:10:00',
#   True),
#  ('11/21/2022',): ({'Location': 11631.75,
#    'Direction': 'Short',
#    'RR': 62.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('11/21/2023',): ({'Location': 16015.75,
#    'Direction': 'Long',
#    'RR': 35.75,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('11/22/2021',): ({'Location': 16682.25,
#    'Direction': 'Long',
#    'RR': 44.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('11/22/2022',): ({'Location': 11587.75,
#    'Direction': 'Short',
#    'RR': 40.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('11/22/2023',): ({'Location': 16148.25,
#    'Direction': 'Long',
#    'RR': 79.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('11/23/2021',): ({'Location': 16346.75,
#    'Direction': 'Long',
#    'RR': 61.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('11/23/2022',): ({'Location': 11776.5,
#    'Direction': 'Long',
#    'RR': 31.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('11/23/2023',): ({'Location': 16064.0,
#    'Direction': 'Long',
#    'RR': 8.25,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('11/24/2021',): ({'Location': 16136.75,
#    'Direction': 'Short',
#    'RR': 71.75,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('11/24/2022',): ({'Location': 11912.0,
#    'Direction': 'Short',
#    'RR': 6.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('11/24/2023',): None,
#  ('11/25/2021',): ({'Location': 16379.75,
#    'Direction': 'Short',
#    'RR': 11.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('11/25/2022',): None,
#  ('11/26/2021',): ({'Location': 16296.5,
#    'Direction': 'Long',
#    'RR': 62.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('11/27/2023',): ({'Location': 15985.25,
#    'Direction': 'Short',
#    'RR': 52.5,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   False),
#  ('11/28/2022',): ({'Location': 11754.0,
#    'Direction': 'Long',
#    'RR': 60.25,
#    'entry_time': '09:35:00'},
#   '10:25:00',
#   False),
#  ('11/28/2023',): ({'Location': 15973.0,
#    'Direction': 'Short',
#    'RR': 34.75,
#    'entry_time': '09:40:00'},
#   '10:35:00',
#   False),
#  ('11/29/2021',): ({'Location': 16217.75,
#    'Direction': 'Short',
#    'RR': 64.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('11/29/2022',): ({'Location': 11597.75,
#    'Direction': 'Short',
#    'RR': 30.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('11/29/2023',): ({'Location': 16188.75,
#    'Direction': 'Long',
#    'RR': 42.5,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   False),
#  ('11/3/2021',): ({'Location': 15951.75,
#    'Direction': 'Short',
#    'RR': 45.75,
#    'entry_time': '09:35:00'},
#   '14:00:00',
#   False),
#  ('11/3/2022',): ({'Location': 10790.75,
#    'Direction': 'Short',
#    'RR': 58.0,
#    'entry_time': '09:40:00'},
#   '09:55:00',
#   True),
#  ('11/3/2023',): ({'Location': 15041.25,
#    'Direction': 'Short',
#    'RR': 39.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('11/30/2021',): ({'Location': 16325.0,
#    'Direction': 'Short',
#    'RR': 47.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('11/30/2022',): ({'Location': 11569.5,
#    'Direction': 'Long',
#    'RR': 51.0,
#    'entry_time': '09:35:00'},
#   '11:00:00',
#   False),
#  ('11/30/2023',): ({'Location': 16012.5,
#    'Direction': 'Short',
#    'RR': 39.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('11/4/2021',): ({'Location': 16182.5,
#    'Direction': 'Long',
#    'RR': 25.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('11/4/2022',): ({'Location': 10863.25,
#    'Direction': 'Short',
#    'RR': 100.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('11/5/2021',): ({'Location': 16427.75,
#    'Direction': 'Long',
#    'RR': 37.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('11/6/2023',): ({'Location': 15238.75,
#    'Direction': 'Long',
#    'RR': 35.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('11/7/2022',): ({'Location': 10893.75,
#    'Direction': 'Short',
#    'RR': 75.25,
#    'entry_time': '09:35:00'},
#   '14:15:00',
#   False),
#  ('11/7/2023',): ({'Location': 15234.5,
#    'Direction': 'Short',
#    'RR': 53.0,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('11/8/2021',): ({'Location': 16376.75,
#    'Direction': 'Long',
#    'RR': 45.0,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('11/8/2022',): ({'Location': 11031.0,
#    'Direction': 'Short',
#    'RR': 52.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('11/8/2023',): ({'Location': 15411.0,
#    'Direction': 'Long',
#    'RR': 37.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('11/9/2021',): ({'Location': 16361.5,
#    'Direction': 'Short',
#    'RR': 30.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('11/9/2022',): ({'Location': 11019.0,
#    'Direction': 'Long',
#    'RR': 50.25,
#    'entry_time': '09:45:00'},
#   '09:55:00',
#   False),
#  ('11/9/2023',): ({'Location': 15381.0,
#    'Direction': 'Short',
#    'RR': 38.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('12/1/2021',): ({'Location': 16282.0,
#    'Direction': 'Short',
#    'RR': 72.0,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('12/1/2022',): ({'Location': 12081.0,
#    'Direction': 'Long',
#    'RR': 49.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('12/1/2023',): ({'Location': 15885.5,
#    'Direction': 'Short',
#    'RR': 50.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('12/10/2021',): ({'Location': 16318.0,
#    'Direction': 'Long',
#    'RR': 62.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('12/11/2023',): ({'Location': 16139.0,
#    'Direction': 'Long',
#    'RR': 70.5,
#    'entry_time': '09:40:00'},
#   '13:00:00',
#   True),
#  ('12/12/2022',): ({'Location': 11569.0,
#    'Direction': 'Short',
#    'RR': 29.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('12/12/2023',): ({'Location': 16408.5,
#    'Direction': 'Short',
#    'RR': 40.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('12/13/2021',): ({'Location': 16279.75,
#    'Direction': 'Short',
#    'RR': 57.5,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   True),
#  ('12/13/2022',): ({'Location': 12094.5,
#    'Direction': 'Short',
#    'RR': 82.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('12/13/2023',): ({'Location': 16644.25,
#    'Direction': 'Long',
#    'RR': 38.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('12/14/2021',): ({'Location': 15933.5,
#    'Direction': 'Long',
#    'RR': 77.25,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   False),
#  ('12/14/2022',): ({'Location': 11988.25,
#    'Direction': 'Long',
#    'RR': 58.5,
#    'entry_time': '09:35:00'},
#   '11:00:00',
#   True),
#  ('12/14/2023',): ({'Location': 16857.75,
#    'Direction': 'Long',
#    'RR': 46.5,
#    'entry_time': '09:40:00'},
#   '10:05:00',
#   False),
#  ('12/15/2021',): ({'Location': 15865.0,
#    'Direction': 'Short',
#    'RR': 63.0,
#    'entry_time': '09:35:00'},
#   '11:30:00',
#   True),
#  ('12/15/2022',): ({'Location': 11630.5,
#    'Direction': 'Short',
#    'RR': 85.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('12/15/2023',): ({'Location': 16818.5,
#    'Direction': 'Long',
#    'RR': 38.75,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   True),
#  ('12/16/2021',): ({'Location': 16333.0,
#    'Direction': 'Long',
#    'RR': 50.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('12/16/2022',): ({'Location': 11406.5,
#    'Direction': 'Short',
#    'RR': 51.5,
#    'entry_time': '09:40:00'},
#   '09:45:00',
#   False),
#  ('12/17/2021',): ({'Location': 15688.75,
#    'Direction': 'Short',
#    'RR': 102.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('12/18/2023',): ({'Location': 16871.5,
#    'Direction': 'Long',
#    'RR': 39.25,
#    'entry_time': '09:35:00'},
#   '11:40:00',
#   True),
#  ('12/19/2022',): ({'Location': 11287.0,
#    'Direction': 'Short',
#    'RR': 72.25,
#    'entry_time': '09:35:00'},
#   '11:00:00',
#   True),
#  ('12/19/2023',): None,
#  ('12/2/2021',): ({'Location': 15873.75,
#    'Direction': 'Long',
#    'RR': 85.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('12/2/2022',): ({'Location': 11844.0,
#    'Direction': 'Short',
#    'RR': 71.75,
#    'entry_time': '09:50:00'},
#   '10:10:00',
#   False),
#  ('12/20/2021',): ({'Location': 15606.0,
#    'Direction': 'Long',
#    'RR': 63.25,
#    'entry_time': '09:35:00'},
#   '10:55:00',
#   False),
#  ('12/20/2022',): ({'Location': 11105.0,
#    'Direction': 'Short',
#    'RR': 46.75,
#    'entry_time': '09:40:00'},
#   '09:55:00',
#   False),
#  ('12/20/2023',): ({'Location': 16994.5,
#    'Direction': 'Long',
#    'RR': 23.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('12/21/2021',): ({'Location': 15751.25,
#    'Direction': 'Short',
#    'RR': 47.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('12/21/2022',): ({'Location': 11230.25,
#    'Direction': 'Long',
#    'RR': 46.25,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('12/21/2023',): ({'Location': 16910.75,
#    'Direction': 'Short',
#    'RR': 48.25,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('12/22/2021',): ({'Location': 15970.75,
#    'Direction': 'Long',
#    'RR': 37.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('12/22/2022',): ({'Location': 11136.75,
#    'Direction': 'Short',
#    'RR': 71.75,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('12/22/2023',): ({'Location': 16994.25,
#    'Direction': 'Short',
#    'RR': 28.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('12/23/2021',): ({'Location': 16218.5,
#    'Direction': 'Long',
#    'RR': 42.25,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   True),
#  ('12/23/2022',): ({'Location': 10979.75,
#    'Direction': 'Short',
#    'RR': 71.25,
#    'entry_time': '09:35:00'},
#   '10:25:00',
#   False),
#  ('12/26/2023',): ({'Location': 17032.75,
#    'Direction': 'Long',
#    'RR': 27.5,
#    'entry_time': '09:35:00'},
#   '10:40:00',
#   True),
#  ('12/27/2021',): ({'Location': 16415.75,
#    'Direction': 'Long',
#    'RR': 71.5,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   True),
#  ('12/27/2022',): ({'Location': 11011.0,
#    'Direction': 'Short',
#    'RR': 45.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('12/27/2023',): ({'Location': 17122.0,
#    'Direction': 'Long',
#    'RR': 30.5,
#    'entry_time': '10:00:00'},
#   '10:10:00',
#   False),
#  ('12/28/2021',): ({'Location': 16557.25,
#    'Direction': 'Short',
#    'RR': 51.5,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   True),
#  ('12/28/2022',): ({'Location': 10977.0,
#    'Direction': 'Long',
#    'RR': 115.5,
#    'entry_time': '09:35:00'},
#   '10:55:00',
#   False),
#  ('12/28/2023',): ({'Location': 17123.5,
#    'Direction': 'Short',
#    'RR': 35.75,
#    'entry_time': '09:35:00'},
#   '15:50:00',
#   True),
#  ('12/29/2021',): ({'Location': 16545.25,
#    'Direction': 'Long',
#    'RR': 53.5,
#    'entry_time': '09:40:00'},
#   '09:45:00',
#   False),
#  ('12/29/2022',): ({'Location': 10914.0,
#    'Direction': 'Long',
#    'RR': 57.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('12/29/2023',): ({'Location': 17081.0,
#    'Direction': 'Short',
#    'RR': 19.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('12/3/2021',): ({'Location': 16011.25,
#    'Direction': 'Short',
#    'RR': 79.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('12/30/2021',): ({'Location': 16510.0,
#    'Direction': 'Long',
#    'RR': 47.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('12/30/2022',): ({'Location': 10885.0,
#    'Direction': 'Short',
#    'RR': 63.0,
#    'entry_time': '09:45:00'},
#   '10:45:00',
#   False),
#  ('12/31/2021',): ({'Location': 16460.0,
#    'Direction': 'Long',
#    'RR': 54.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('12/4/2023',): ({'Location': 15841.25,
#    'Direction': 'Short',
#    'RR': 35.5,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   True),
#  ('12/5/2022',): ({'Location': 11947.75,
#    'Direction': 'Long',
#    'RR': 36.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('12/5/2023',): ({'Location': 15810.25,
#    'Direction': 'Long',
#    'RR': 27.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('12/6/2021',): ({'Location': 15625.0,
#    'Direction': 'Short',
#    'RR': 135.75,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   False),
#  ('12/6/2022',): ({'Location': 11768.75,
#    'Direction': 'Short',
#    'RR': 37.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('12/6/2023',): ({'Location': 15965.5,
#    'Direction': 'Short',
#    'RR': 72.5,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   True),
#  ('12/7/2021',): ({'Location': 16161.5,
#    'Direction': 'Long',
#    'RR': 42.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('12/7/2022',): ({'Location': 11558.25,
#    'Direction': 'Long',
#    'RR': 63.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('12/7/2023',): ({'Location': 15968.5,
#    'Direction': 'Long',
#    'RR': 61.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('12/8/2021',): ({'Location': 16253.5,
#    'Direction': 'Short',
#    'RR': 80.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('12/8/2022',): ({'Location': 11514.0,
#    'Direction': 'Short',
#    'RR': 58.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('12/8/2023',): ({'Location': 15995.0,
#    'Direction': 'Long',
#    'RR': 48.0,
#    'entry_time': '09:40:00'},
#   '10:00:00',
#   True),
#  ('12/9/2021',): ({'Location': 16390.25,
#    'Direction': 'Long',
#    'RR': 55.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('12/9/2022',): ({'Location': 11618.0,
#    'Direction': 'Long',
#    'RR': 68.25,
#    'entry_time': '09:35:00'},
#   '10:55:00',
#   True),
#  ('2/1/2022',): ({'Location': 14865.25,
#    'Direction': 'Short',
#    'RR': 87.0,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('2/1/2023',): ({'Location': 12104.5,
#    'Direction': 'Short',
#    'RR': 51.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('2/1/2024',): ({'Location': 17334.5,
#    'Direction': 'Long',
#    'RR': 40.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('2/10/2022',): ({'Location': 14793.25,
#    'Direction': 'Long',
#    'RR': 58.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('2/10/2023',): ({'Location': 12380.5,
#    'Direction': 'Long',
#    'RR': 50.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/11/2022',): ({'Location': 14697.75,
#    'Direction': 'Short',
#    'RR': 52.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('2/12/2024',): ({'Location': 18050.0,
#    'Direction': 'Long',
#    'RR': 43.0,
#    'entry_time': '09:35:00'},
#   '11:25:00',
#   True),
#  ('2/13/2023',): ({'Location': 12365.5,
#    'Direction': 'Short',
#    'RR': 44.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/13/2024',): ({'Location': 17638.25,
#    'Direction': 'Long',
#    'RR': 51.75,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   True),
#  ('2/14/2022',): ({'Location': 14262.5,
#    'Direction': 'Long',
#    'RR': 80.75,
#    'entry_time': '09:35:00'},
#   '11:15:00',
#   True),
#  ('2/14/2023',): ({'Location': 12479.25,
#    'Direction': 'Long',
#    'RR': 89.0,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('2/14/2024',): ({'Location': 17783.75,
#    'Direction': 'Short',
#    'RR': 35.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('2/15/2022',): ({'Location': 14508.0,
#    'Direction': 'Long',
#    'RR': 61.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('2/15/2023',): ({'Location': 12605.75,
#    'Direction': 'Long',
#    'RR': 53.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('2/15/2024',): ({'Location': 17870.75,
#    'Direction': 'Short',
#    'RR': 32.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('2/16/2022',): ({'Location': 14469.75,
#    'Direction': 'Short',
#    'RR': 47.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('2/16/2023',): ({'Location': 12522.25,
#    'Direction': 'Short',
#    'RR': 35.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/16/2024',): ({'Location': 17886.5,
#    'Direction': 'Short',
#    'RR': 43.75,
#    'entry_time': '09:40:00'},
#   '09:50:00',
#   True),
#  ('2/17/2022',): ({'Location': 14484.75,
#    'Direction': 'Long',
#    'RR': 35.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('2/17/2023',): ({'Location': 12417.25,
#    'Direction': 'Long',
#    'RR': 44.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/18/2022',): ({'Location': 14149.25,
#    'Direction': 'Short',
#    'RR': 69.25,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('2/19/2024',): ({'Location': 17801.75,
#    'Direction': 'Long',
#    'RR': 17.0,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   False),
#  ('2/2/2022',): ({'Location': 15172.5,
#    'Direction': 'Long',
#    'RR': 80.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/2/2023',): ({'Location': 12677.75,
#    'Direction': 'Short',
#    'RR': 54.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/2/2024',): ({'Location': 17521.5,
#    'Direction': 'Long',
#    'RR': 56.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('2/20/2023',): ({'Location': 12385.75,
#    'Direction': 'Short',
#    'RR': 10.25,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   True),
#  ('2/20/2024',): ({'Location': 17649.25,
#    'Direction': 'Short',
#    'RR': 75.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('2/21/2022',): ({'Location': 13860.5,
#    'Direction': 'Short',
#    'RR': 23.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('2/21/2023',): ({'Location': 12252.5,
#    'Direction': 'Long',
#    'RR': 32.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('2/21/2024',): ({'Location': 17463.75,
#    'Direction': 'Short',
#    'RR': 48.25,
#    'entry_time': '09:40:00'},
#   '10:00:00',
#   False),
#  ('2/22/2022',): ({'Location': 13870.0,
#    'Direction': 'Short',
#    'RR': 63.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/22/2023',): ({'Location': 12154.0,
#    'Direction': 'Long',
#    'RR': 38.75,
#    'entry_time': '09:40:00'},
#   '10:00:00',
#   False),
#  ('2/22/2024',): ({'Location': 17919.75,
#    'Direction': 'Long',
#    'RR': 56.0,
#    'entry_time': '09:45:00'},
#   '11:15:00',
#   True),
#  ('2/23/2022',): ({'Location': 14026.75,
#    'Direction': 'Long',
#    'RR': 50.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/23/2023',): ({'Location': 12226.5,
#    'Direction': 'Short',
#    'RR': 33.5,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('2/23/2024',): ({'Location': 18140.25,
#    'Direction': 'Long',
#    'RR': 43.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('2/24/2022',): ({'Location': 13216.0,
#    'Direction': 'Long',
#    'RR': 158.25,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   True),
#  ('2/24/2023',): ({'Location': 12020.75,
#    'Direction': 'Long',
#    'RR': 40.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('2/25/2022',): ({'Location': 14001.75,
#    'Direction': 'Long',
#    'RR': 82.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/26/2024',): ({'Location': 18009.5,
#    'Direction': 'Short',
#    'RR': 41.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('2/27/2023',): ({'Location': 12116.0,
#    'Direction': 'Short',
#    'RR': 27.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('2/27/2024',): ({'Location': 17997.75,
#    'Direction': 'Short',
#    'RR': 29.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('2/28/2022',): ({'Location': 14108.0,
#    'Direction': 'Long',
#    'RR': 75.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/28/2023',): ({'Location': 12071.0,
#    'Direction': 'Long',
#    'RR': 29.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('2/28/2024',): ({'Location': 17943.75,
#    'Direction': 'Long',
#    'RR': 42.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('2/29/2024',): ({'Location': 18067.25,
#    'Direction': 'Long',
#    'RR': 46.75,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   False),
#  ('2/3/2022',): ({'Location': 14744.5,
#    'Direction': 'Long',
#    'RR': 67.25,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   True),
#  ('2/3/2023',): ({'Location': 12637.75,
#    'Direction': 'Long',
#    'RR': 79.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('2/4/2022',): ({'Location': 14454.75,
#    'Direction': 'Short',
#    'RR': 111.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/5/2024',): ({'Location': 17707.5,
#    'Direction': 'Short',
#    'RR': 30.0,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('2/6/2023',): ({'Location': 12560.25,
#    'Direction': 'Long',
#    'RR': 58.0,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   False),
#  ('2/6/2024',): ({'Location': 17720.75,
#    'Direction': 'Short',
#    'RR': 47.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('2/7/2022',): ({'Location': 14726.75,
#    'Direction': 'Long',
#    'RR': 57.0,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('2/7/2023',): ({'Location': 12523.5,
#    'Direction': 'Long',
#    'RR': 29.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('2/7/2024',): ({'Location': 17744.0,
#    'Direction': 'Short',
#    'RR': 34.5,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   False),
#  ('2/8/2022',): ({'Location': 14564.25,
#    'Direction': 'Long',
#    'RR': 63.0,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('2/8/2023',): ({'Location': 12733.5,
#    'Direction': 'Long',
#    'RR': 50.0,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('2/8/2024',): ({'Location': 17845.5,
#    'Direction': 'Long',
#    'RR': 26.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('2/9/2022',): ({'Location': 14936.75,
#    'Direction': 'Long',
#    'RR': 48.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('2/9/2023',): ({'Location': 12679.5,
#    'Direction': 'Short',
#    'RR': 49.25,
#    'entry_time': '09:35:00'},
#   '10:25:00',
#   True),
#  ('2/9/2024',): ({'Location': 17883.75,
#    'Direction': 'Short',
#    'RR': 27.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('3/1/2022',): ({'Location': 14221.0,
#    'Direction': 'Long',
#    'RR': 67.5,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   False),
#  ('3/1/2023',): ({'Location': 12019.25,
#    'Direction': 'Short',
#    'RR': 41.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('3/1/2024',): ({'Location': 18144.75,
#    'Direction': 'Long',
#    'RR': 51.25,
#    'entry_time': '10:00:00'},
#   '10:15:00',
#   True),
#  ('3/10/2022',): ({'Location': 13498.5,
#    'Direction': 'Short',
#    'RR': 80.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('3/10/2023',): ({'Location': 11960.75,
#    'Direction': 'Short',
#    'RR': 67.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('3/11/2022',): ({'Location': 13662.5,
#    'Direction': 'Short',
#    'RR': 61.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('3/11/2024',): ({'Location': 17989.75,
#    'Direction': 'Long',
#    'RR': 83.0,
#    'entry_time': '09:40:00'},
#   '09:55:00',
#   False),
#  ('3/12/2024',): ({'Location': 18263.25,
#    'Direction': 'Short',
#    'RR': 76.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('3/13/2023',): ({'Location': 11753.0,
#    'Direction': 'Short',
#    'RR': 63.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('3/13/2024',): ({'Location': 18382.5,
#    'Direction': 'Short',
#    'RR': 47.5,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('3/14/2022',): ({'Location': 13221.75,
#    'Direction': 'Short',
#    'RR': 69.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('3/14/2023',): ({'Location': 12104.25,
#    'Direction': 'Long',
#    'RR': 34.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('3/14/2024',): ({'Location': 18384.25,
#    'Direction': 'Long',
#    'RR': 48.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('3/15/2022',): ({'Location': 13149.75,
#    'Direction': 'Short',
#    'RR': 59.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('3/15/2023',): ({'Location': 12270.25,
#    'Direction': 'Long',
#    'RR': 72.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('3/15/2024',): ({'Location': 18127.0,
#    'Direction': 'Short',
#    'RR': 47.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('3/16/2022',): ({'Location': 13658.0,
#    'Direction': 'Long',
#    'RR': 46.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('3/16/2023',): ({'Location': 12321.0,
#    'Direction': 'Short',
#    'RR': 42.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('3/17/2022',): ({'Location': 13889.25,
#    'Direction': 'Long',
#    'RR': 70.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('3/17/2023',): ({'Location': 12736.5,
#    'Direction': 'Long',
#    'RR': 40.75,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('3/18/2022',): ({'Location': 14065.0,
#    'Direction': 'Long',
#    'RR': 70.25,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('3/18/2024',): ({'Location': 18329.0,
#    'Direction': 'Long',
#    'RR': 51.75,
#    'entry_time': '09:35:00'},
#   '10:25:00',
#   True),
#  ('3/19/2024',): ({'Location': 18102.75,
#    'Direction': 'Short',
#    'RR': 50.0,
#    'entry_time': '09:35:00'},
#   '11:30:00',
#   False),
#  ('3/2/2022',): ({'Location': 14021.5,
#    'Direction': 'Short',
#    'RR': 67.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('3/2/2023',): ({'Location': 11883.25,
#    'Direction': 'Long',
#    'RR': 37.25,
#    'entry_time': '09:45:00'},
#   '10:00:00',
#   True),
#  ('3/20/2023',): ({'Location': 12577.75,
#    'Direction': 'Short',
#    'RR': 55.5,
#    'entry_time': '09:35:00'},
#   '10:45:00',
#   False),
#  ('3/20/2024',): ({'Location': 18301.75,
#    'Direction': 'Short',
#    'RR': 33.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('3/21/2022',): ({'Location': 14408.25,
#    'Direction': 'Long',
#    'RR': 50.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('3/21/2023',): ({'Location': 12773.75,
#    'Direction': 'Short',
#    'RR': 41.75,
#    'entry_time': '09:45:00'},
#   '09:55:00',
#   False),
#  ('3/21/2024',): ({'Location': 18692.5,
#    'Direction': 'Long',
#    'RR': 37.5,
#    'entry_time': '09:40:00'},
#   '09:45:00',
#   False),
#  ('3/22/2022',): ({'Location': 14433.75,
#    'Direction': 'Long',
#    'RR': 60.0,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('3/22/2023',): ({'Location': 12878.75,
#    'Direction': 'Long',
#    'RR': 27.75,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   True),
#  ('3/22/2024',): ({'Location': 18545.25,
#    'Direction': 'Long',
#    'RR': 28.0,
#    'entry_time': '09:40:00'},
#   '09:45:00',
#   False),
#  ('3/23/2022',): ({'Location': 14492.5,
#    'Direction': 'Short',
#    'RR': 54.75,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   False),
#  ('3/23/2023',): ({'Location': 12888.5,
#    'Direction': 'Long',
#    'RR': 35.25,
#    'entry_time': '09:40:00'},
#   '09:45:00',
#   False),
#  ('3/24/2022',): ({'Location': 14485.75,
#    'Direction': 'Short',
#    'RR': 43.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('3/24/2023',): ({'Location': 12784.75,
#    'Direction': 'Short',
#    'RR': 60.25,
#    'entry_time': '09:35:00'},
#   '12:00:00',
#   False),
#  ('3/25/2022',): ({'Location': 14742.5,
#    'Direction': 'Short',
#    'RR': 46.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('3/25/2024',): ({'Location': 18441.75,
#    'Direction': 'Short',
#    'RR': 39.25,
#    'entry_time': '09:40:00'},
#   '09:50:00',
#   False),
#  ('3/26/2024',): ({'Location': 18589.75,
#    'Direction': 'Long',
#    'RR': 40.0,
#    'entry_time': '09:35:00'},
#   '10:25:00',
#   False),
#  ('3/27/2023',): ({'Location': 12891.0,
#    'Direction': 'Short',
#    'RR': 35.0,
# ...
#   True),
#  ('8/14/2023',): ({'Location': 15078.5,
#    'Direction': 'Long',
#    'RR': 43.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('8/14/2024',): ({'Location': 19105.0,
#    'Direction': 'Short',
#    'RR': 70.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('8/15/2022',): ({'Location': 13601.0,
#    'Direction': 'Long',
#    'RR': 67.0,
#    'entry_time': '09:35:00'},
#   '12:55:00',
#   True),
#  ('8/15/2023',): ({'Location': 15245.0,
#    'Direction': 'Long',
#    'RR': 33.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('8/15/2024',): ({'Location': 19381.75,
#    'Direction': 'Long',
#    'RR': 45.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('8/16/2022',): ({'Location': 13627.0,
#    'Direction': 'Short',
#    'RR': 32.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('8/16/2023',): ({'Location': 15090.75,
#    'Direction': 'Long',
#    'RR': 40.0,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   True),
#  ('8/16/2024',): ({'Location': 19514.0,
#    'Direction': 'Long',
#    'RR': 51.75,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   True),
#  ('8/17/2022',): ({'Location': 13542.25,
#    'Direction': 'Long',
#    'RR': 30.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('8/17/2023',): ({'Location': 14966.25,
#    'Direction': 'Short',
#    'RR': 41.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('8/18/2022',): ({'Location': 13438.5,
#    'Direction': 'Short',
#    'RR': 59.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('8/18/2023',): ({'Location': 14674.25,
#    'Direction': 'Long',
#    'RR': 51.0,
#    'entry_time': '09:45:00'},
#   '10:00:00',
#   False),
#  ('8/19/2022',): ({'Location': 13388.25,
#    'Direction': 'Short',
#    'RR': 37.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('8/19/2024',): ({'Location': 19583.25,
#    'Direction': 'Short',
#    'RR': 31.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('8/2/2022',): ({'Location': 12917.75,
#    'Direction': 'Long',
#    'RR': 65.0,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   False),
#  ('8/2/2023',): ({'Location': 15621.5,
#    'Direction': 'Short',
#    'RR': 47.5,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('8/2/2024',): ({'Location': 18654.75,
#    'Direction': 'Long',
#    'RR': 113.0,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   False),
#  ('8/20/2024',): ({'Location': 19865.0,
#    'Direction': 'Long',
#    'RR': 48.25,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('8/21/2023',): ({'Location': 14848.5,
#    'Direction': 'Long',
#    'RR': 43.25,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('8/21/2024',): ({'Location': 19818.75,
#    'Direction': 'Short',
#    'RR': 30.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('8/22/2022',): ({'Location': 13035.5,
#    'Direction': 'Short',
#    'RR': 57.0,
#    'entry_time': '09:35:00'},
#   '10:20:00',
#   True),
#  ('8/22/2023',): ({'Location': 15063.75,
#    'Direction': 'Short',
#    'RR': 28.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('8/22/2024',): ({'Location': 19986.75,
#    'Direction': 'Short',
#    'RR': 38.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('8/23/2022',): ({'Location': 12943.5,
#    'Direction': 'Long',
#    'RR': 50.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('8/23/2023',): ({'Location': 15038.0,
#    'Direction': 'Long',
#    'RR': 38.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('8/23/2024',): ({'Location': 19765.0,
#    'Direction': 'Long',
#    'RR': 58.75,
#    'entry_time': '10:00:00'},
#   '10:05:00',
#   True),
#  ('8/24/2022',): ({'Location': 12856.5,
#    'Direction': 'Short',
#    'RR': 50.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('8/24/2023',): ({'Location': 15252.25,
#    'Direction': 'Short',
#    'RR': 87.75,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('8/25/2022',): ({'Location': 12973.25,
#    'Direction': 'Short',
#    'RR': 41.25,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   False),
#  ('8/25/2023',): ({'Location': 14934.5,
#    'Direction': 'Long',
#    'RR': 42.5,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('8/26/2022',): ({'Location': 13157.5,
#    'Direction': 'Long',
#    'RR': 41.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('8/26/2024',): ({'Location': 19741.75,
#    'Direction': 'Short',
#    'RR': 60.0,
#    'entry_time': '09:45:00'},
#   '10:05:00',
#   True),
#  ('8/27/2024',): ({'Location': 19493.0,
#    'Direction': 'Short',
#    'RR': 46.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('8/28/2023',): ({'Location': 15114.75,
#    'Direction': 'Long',
#    'RR': 54.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('8/28/2024',): ({'Location': 19620.25,
#    'Direction': 'Short',
#    'RR': 36.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('8/29/2022',): ({'Location': 12568.75,
#    'Direction': 'Long',
#    'RR': 90.25,
#    'entry_time': '09:35:00'},
#   '10:50:00',
#   False),
#  ('8/29/2023',): ({'Location': 15112.5,
#    'Direction': 'Long',
#    'RR': 50.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('8/29/2024',): ({'Location': 19590.75,
#    'Direction': 'Long',
#    'RR': 112.75,
#    'entry_time': '09:35:00'},
#   '14:30:00',
#   False),
#  ('8/3/2022',): ({'Location': 13058.75,
#    'Direction': 'Long',
#    'RR': 69.5,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('8/3/2023',): ({'Location': 15394.0,
#    'Direction': 'Long',
#    'RR': 43.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('8/30/2022',): ({'Location': 12538.5,
#    'Direction': 'Short',
#    'RR': 49.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('8/30/2023',): ({'Location': 15445.25,
#    'Direction': 'Long',
#    'RR': 33.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('8/30/2024',): ({'Location': 19515.25,
#    'Direction': 'Short',
#    'RR': 62.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('8/31/2022',): ({'Location': 12410.5,
#    'Direction': 'Short',
#    'RR': 67.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('8/31/2023',): None,
#  ('8/4/2022',): ({'Location': 13291.5,
#    'Direction': 'Long',
#    'RR': 46.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('8/4/2023',): ({'Location': 15558.75,
#    'Direction': 'Long',
#    'RR': 62.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('8/5/2022',): ({'Location': 13184.25,
#    'Direction': 'Long',
#    'RR': 70.0,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   True),
#  ('8/5/2024',): ({'Location': 17709.25,
#    'Direction': 'Long',
#    'RR': 200.25,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('8/6/2024',): ({'Location': 18065.25,
#    'Direction': 'Short',
#    'RR': 109.0,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('8/7/2023',): ({'Location': 15412.75,
#    'Direction': 'Short',
#    'RR': 60.75,
#    'entry_time': '09:40:00'},
#   '11:15:00',
#   True),
#  ('8/7/2024',): ({'Location': 18522.25,
#    'Direction': 'Long',
#    'RR': 83.75,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   False),
#  ('8/8/2022',): ({'Location': 13319.5,
#    'Direction': 'Long',
#    'RR': 87.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('8/8/2023',): ({'Location': 15350.0,
#    'Direction': 'Short',
#    'RR': 29.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('8/8/2024',): ({'Location': 18175.75,
#    'Direction': 'Short',
#    'RR': 67.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   True),
#  ('8/9/2022',): None,
#  ('8/9/2023',): ({'Location': 15336.25,
#    'Direction': 'Short',
#    'RR': 32.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('8/9/2024',): ({'Location': 18507.5,
#    'Direction': 'Long',
#    'RR': 56.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('9/1/2022',): ({'Location': 12192.0,
#    'Direction': 'Long',
#    'RR': 51.75,
#    'entry_time': '09:40:00'},
#   '10:00:00',
#   False),
#  ('9/1/2023',): ({'Location': 15610.5,
#    'Direction': 'Short',
#    'RR': 42.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('9/10/2024',): ({'Location': 18747.25,
#    'Direction': 'Short',
#    'RR': 74.75,
#    'entry_time': '09:35:00'},
#   '11:50:00',
#   True),
#  ('9/11/2023',): ({'Location': 15414.5,
#    'Direction': 'Short',
#    'RR': 34.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('9/11/2024',): ({'Location': 18843.75,
#    'Direction': 'Short',
#    'RR': 63.0,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('9/12/2022',): ({'Location': 12686.0,
#    'Direction': 'Long',
#    'RR': 44.75,
#    'entry_time': '09:40:00'},
#   '09:55:00',
#   True),
#  ('9/12/2023',): ({'Location': 15625.75,
#    'Direction': 'Long',
#    'RR': 40.5,
#    'entry_time': '09:40:00'},
#   '10:25:00',
#   False),
#  ('9/12/2024',): ({'Location': 19281.75,
#    'Direction': 'Long',
#    'RR': 71.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('9/13/2022',): ({'Location': 12361.5,
#    'Direction': 'Short',
#    'RR': 65.75,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('9/13/2023',): ({'Location': 15556.0,
#    'Direction': 'Long',
#    'RR': 62.75,
#    'entry_time': '09:40:00'},
#   '10:05:00',
#   False),
#  ('9/13/2024',): ({'Location': 19449.25,
#    'Direction': 'Long',
#    'RR': 51.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('9/14/2022',): ({'Location': 12100.0,
#    'Direction': 'Short',
#    'RR': 80.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('9/14/2023',): ({'Location': 15588.0,
#    'Direction': 'Short',
#    'RR': 51.0,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('9/15/2022',): ({'Location': 12150.25,
#    'Direction': 'Long',
#    'RR': 40.25,
#    'entry_time': '09:40:00'},
#   '09:45:00',
#   True),
#  ('9/15/2023',): ({'Location': 15576.75,
#    'Direction': 'Short',
#    'RR': 51.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('9/16/2022',): ({'Location': 11805.5,
#    'Direction': 'Short',
#    'RR': 66.0,
#    'entry_time': '09:40:00'},
#   '10:10:00',
#   False),
#  ('9/16/2024',): ({'Location': 19341.25,
#    'Direction': 'Short',
#    'RR': 99.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('9/17/2024',): ({'Location': 19536.25,
#    'Direction': 'Short',
#    'RR': 57.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('9/18/2023',): None,
#  ('9/18/2024',): ({'Location': 19688.0,
#    'Direction': 'Short',
#    'RR': 48.75,
#    'entry_time': '09:35:00'},
#   '11:20:00',
#   True),
#  ('9/19/2022',): ({'Location': 11883.75,
#    'Direction': 'Long',
#    'RR': 68.25,
#    'entry_time': '09:40:00'},
#   '10:35:00',
#   True),
#  ('9/19/2023',): ({'Location': 15358.25,
#    'Direction': 'Long',
#    'RR': 34.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('9/19/2024',): ({'Location': 20021.75,
#    'Direction': 'Short',
#    'RR': 37.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('9/2/2022',): ({'Location': 12318.25,
#    'Direction': 'Short',
#    'RR': 97.0,
#    'entry_time': '09:35:00'},
#   '10:30:00',
#   False),
#  ('9/2/2024',): ({'Location': 19616.5,
#    'Direction': 'Short',
#    'RR': 15.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('9/20/2022',): ({'Location': 11910.25,
#    'Direction': 'Short',
#    'RR': 37.0,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   False),
#  ('9/20/2023',): ({'Location': 15419.75,
#    'Direction': 'Long',
#    'RR': 45.0,
#    'entry_time': '09:40:00'},
#   '10:10:00',
#   False),
#  ('9/20/2024',): ({'Location': 20076.25,
#    'Direction': 'Long',
#    'RR': 45.75,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('9/21/2022',): ({'Location': 11940.25,
#    'Direction': 'Short',
#    'RR': 37.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('9/21/2023',): ({'Location': 15013.25,
#    'Direction': 'Long',
#    'RR': 38.5,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('9/22/2022',): ({'Location': 11632.0,
#    'Direction': 'Short',
#    'RR': 50.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('9/22/2023',): ({'Location': 14914.25,
#    'Direction': 'Short',
#    'RR': 27.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('9/23/2022',): ({'Location': 11427.5,
#    'Direction': 'Short',
#    'RR': 43.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('9/23/2024',): ({'Location': 20035.0,
#    'Direction': 'Short',
#    'RR': 51.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('9/24/2024',): ({'Location': 20100.75,
#    'Direction': 'Short',
#    'RR': 53.5,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('9/25/2023',): ({'Location': 14835.75,
#    'Direction': 'Long',
#    'RR': 53.5,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('9/25/2024',): ({'Location': 20193.75,
#    'Direction': 'Long',
#    'RR': 56.0,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   True),
#  ('9/26/2022',): ({'Location': 11433.25,
#    'Direction': 'Long',
#    'RR': 91.0,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   True),
#  ('9/26/2023',): ({'Location': 14838.25,
#    'Direction': 'Long',
#    'RR': 35.75,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('9/26/2024',): ({'Location': 20445.5,
#    'Direction': 'Short',
#    'RR': 72.25,
#    'entry_time': '09:35:00'},
#   '10:25:00',
#   True),
#  ('9/27/2022',): ({'Location': 11531.0,
#    'Direction': 'Long',
#    'RR': 70.25,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   False),
#  ('9/27/2023',): ({'Location': 14789.5,
#    'Direction': 'Long',
#    'RR': 40.5,
#    'entry_time': '09:40:00'},
#   '10:00:00',
#   False),
#  ('9/27/2024',): ({'Location': 20339.0,
#    'Direction': 'Short',
#    'RR': 44.25,
#    'entry_time': '09:35:00'},
#   '10:10:00',
#   True),
#  ('9/28/2022',): ({'Location': 11340.25,
#    'Direction': 'Long',
#    'RR': 74.5,
#    'entry_time': '09:40:00'},
#   '10:35:00',
#   True),
#  ('9/28/2023',): ({'Location': 14712.25,
#    'Direction': 'Long',
#    'RR': 51.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('9/29/2022',): ({'Location': 11362.5,
#    'Direction': 'Short',
#    'RR': 40.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('9/29/2023',): ({'Location': 14985.5,
#    'Direction': 'Short',
#    'RR': 31.0,
#    'entry_time': '09:35:00'},
#   '09:45:00',
#   False),
#  ('9/3/2024',): ({'Location': 19404.75,
#    'Direction': 'Short',
#    'RR': 78.75,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('9/30/2022',): ({'Location': 11173.25,
#    'Direction': 'Short',
#    'RR': 72.25,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   False),
#  ('9/30/2024',): ({'Location': 20233.5,
#    'Direction': 'Long',
#    'RR': 65.0,
#    'entry_time': '09:35:00'},
#   '10:05:00',
#   False),
#  ('9/4/2023',): ({'Location': 15564.5,
#    'Direction': 'Long',
#    'RR': 10.5,
#    'entry_time': '09:35:00'},
#   '09:50:00',
#   True),
#  ('9/4/2024',): ({'Location': 18928.75,
#    'Direction': 'Long',
#    'RR': 69.0,
#    'entry_time': '09:40:00'},
#   '10:00:00',
#   False),
#  ('9/5/2022',): ({'Location': 12115.25,
#    'Direction': 'Long',
#    'RR': 11.25,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('9/5/2023',): ({'Location': 15460.0,
#    'Direction': 'Short',
#    'RR': 38.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('9/5/2024',): ({'Location': 18946.75,
#    'Direction': 'Long',
#    'RR': 62.0,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('9/6/2022',): ({'Location': 12097.5,
#    'Direction': 'Short',
#    'RR': 71.75,
#    'entry_time': '09:35:00'},
#   '09:55:00',
#   True),
#  ('9/6/2023',): ({'Location': 15467.0,
#    'Direction': 'Short',
#    'RR': 37.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('9/6/2024',): ({'Location': 18884.75,
#    'Direction': 'Short',
#    'RR': 82.75,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   True),
#  ('9/7/2022',): ({'Location': 12083.25,
#    'Direction': 'Long',
#    'RR': 47.5,
#    'entry_time': '09:35:00'},
#   '10:15:00',
#   False),
#  ('9/7/2023',): ({'Location': 15203.5,
#    'Direction': 'Long',
#    'RR': 46.25,
#    'entry_time': '09:35:00'},
#   '10:40:00',
#   True),
#  ('9/8/2022',): ({'Location': 12118.25,
#    'Direction': 'Short',
#    'RR': 58.5,
#    'entry_time': '09:35:00'},
#   '09:40:00',
#   False),
#  ('9/8/2023',): ({'Location': 15350.0,
#    'Direction': 'Long',
#    'RR': 80.25,
#    'entry_time': '09:35:00'},
#   '14:55:00',
#   False),
#  ('9/9/2022',): ({'Location': 12469.75,
#    'Direction': 'Long',
#    'RR': 54.5,
#    'entry_time': '09:35:00'},
#   '10:00:00',
#   True),
#  ('9/9/2024',): ({'Location': 18664.75,
#    'Direction': 'Long',
#    'RR': 60.25,
#    'entry_time': '09:35:00'},
#   '10:30:00',
#   False)}

# %% [markdown]
# results should be good

# %%
formatted_data = {
    str(key): value for key, value in results.items()
}

formatted_data = {key.strip("()'"): value for key, value in formatted_data.items()}
formatted_data = {key.strip(",'"): value for key, value in formatted_data.items()}


# Save to a JSON file
with open('./IntermediateData/zanek_initial_results.json', 'w') as f:
    json.dump(formatted_data, f, indent=4)
